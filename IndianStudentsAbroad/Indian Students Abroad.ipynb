# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('IndianStudentsAbroad.xls')

# %%
df1 = df.iloc[:86,[1,2,3]]

# %%
print(df1)
# Out:
#                                 Country  Estimated Indian Students Studying  \
# 0                               Armenia                                 900
# 1                             Australia                               63283
# 2                               Austria                                 300
# 3                            Azerbaijan                                   9
# 4                               Bahrain                               27000
# ..                                  ...                                 ...
# 81                              Ukraine                                8000
# 82        United Arab Emirates\n(Dubai)                                 500
# 83            United Kingdom\n(2015-16)                               14830
# 84  United States of America\n(2015-16)                              206708
# 85                           Uzbekistan                                   2
#
#     Percentage
# 0     0.162619
# 1    11.434483
# ...

# %%
df2 = df1.sort_values(by='Percentage', ascending=False)
df2['Country'] = df2['Country'].replace('\n','',regex=True)
print(df2)
# Out:
#                               Country  Estimated Indian Students Studying  \
# 84  United States of America(2015-16)                              206708
# 13                             Canada                              100000
# 1                           Australia                               63283
# 55                        New Zealand                               30000
# 4                             Bahrain                               27000
# ..                                ...                                 ...
# 9                  Bosnia Herzegovina                                   2
# 28                             Greece                                   2
# 85                         Uzbekistan                                   2
# 66                             Serbia                                   1
# 52                           Mongolia                                   1
#
#     Percentage
# 84   37.349668
# 13   18.068806
# 1    11.434483
# ...

# %%
dftop = df2.iloc[0:11,[0,2]]
print(dftop)
# Out:
#                               Country  Percentage
# 84  United States of America(2015-16)   37.349668
# 13                             Canada   18.068806
# 1                           Australia   11.434483
# 55                        New Zealand    5.420642
# 4                             Bahrain    4.878578
# 15                              China    3.283283
# 83            United Kingdom(2015-16)    2.679604
# 27                            Germany    2.482654
# 59                        Philippines    1.535849
# 81                            Ukraine    1.445504
# 63                 Russian Federation    1.445504

# %%
dftop = dftop.iloc[0:7,:]
dftop = dftop.append([{'Country':'Others','Percentage':16.88493}])
print(dftop)
# Out:
#                               Country  Percentage
# 84  United States of America(2015-16)   37.349668
# 13                             Canada   18.068806
# 1                           Australia   11.434483
# 55                        New Zealand    5.420642
# 4                             Bahrain    4.878578
# 15                              China    3.283283
# 83            United Kingdom(2015-16)    2.679604
# 0                              Others   16.884930

# %%
# %matplotlib notebook
explode = (0,0.2,0,0.2,0,0.2,0,0.2)
colors= ('#adb0ff', '#ffb3ff', '#90d595', '#e48381','#aafbff', '#f7bb5f', '#eafb50','#00FFFF')
plt.pie(dftop['Percentage'], labels=dftop['Country'], explode=explode, colors=colors, autopct='%1.1f%%')
plt.title('Indian Students studying in Other Countries')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('%agecountry.png')

# %%
# %matplotlib notebook
# sns.set_style('darkgrid')
# plt.bar(dftop['Country'], dftop['Percentage'], align='center')
# plt.xlabel('Countries')
# plt.ylabel('Percentage')
# plt.xticks([x for x in range(11)], dftop['Country'], rotation = 45)
# plt.title('Indian Students Abroad')
# plt.legend()
# sns.despine()
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1147">

# %%
data = {'Year':[2000,2006,2010,2013,2016], 'Abroad Going Students':[66713,123000,210649,190358,301406]}
yearDF = pd.DataFrame(data)

# %%
print(yearDF)
# Out:
#    Year  Abroad Going Students
# 0  2000                  66713
# 1  2006                 123000
# 2  2010                 210649
# 3  2013                 190358
# 4  2016                 301406

# %%
# %matplotlib notebook
bw=0.25
plt.plot(yearDF['Year'], yearDF['Abroad Going Students'], marker='o')
plt.xlabel('Year')
plt.ylabel('Indian Students Going Abroad')
plt.title('Indian Students Going Abroad Vs Year')
plt.axis([1999, 2017, 50000, 310000])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.savefig('year.png')
