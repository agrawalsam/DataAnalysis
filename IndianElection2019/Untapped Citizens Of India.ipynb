# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns 
import plotly.graph_objects as go

# %%
filename = 'Votes 2019.xls'
df = pd.read_excel(filename)

# %%
print(df.head())
# Out:
#                   State Name  Total Electors  Total Actual Votes      Male  \
# 0  Andaman & Nicobar Islands          317878              207296    109407
# 1            Andhra Pradesh*        39345717            31607242  15567765
# 2          Arunachal Pradesh          798249              652091    300798
# 3                      Assam        21991112            17986066   9184449
# 4                      Bihar        71063555            40805297  20688548
#
#     Female   Other   Total Voters  EVM Vote  Postal Vote  Migrant Vote  \
# 0     97671       2        207080    207080          216             0
# 1  15818150     709      31386624  31380829       226413             0
# 2    326179       0        626977    626977        25114             0
# 3   8748413      23      17932885  17932885        53181             0
# 4  19978743      53      40667344  40667344       137953             0
#
#    Voters Turnout Percentage
# 0                  65.212440
# ...

# %%
totalelectors = df['Total Electors'].sum()
print(totalelectors)
# Out:
# 910149144

# %%
actualvoters = df['Total Actual Votes'].sum()
print(actualvoters)
# Out:
# 613136854

# %%
femaletotal = df['Female '].sum()
maletotal = df['Male'].sum()
print(maletotal, femaletotal)
# Out:
# 316792980 294035406

# %%
diff = list(df['Female ']>df['Male'])

# %%
votersturnout = (actualvoters/totalelectors)*100

# %%
df['State Name'] = df['State Name'].str.replace('*','', regex=True)

# %%
df['Voters Turnout Percentage'] = df['Voters Turnout Percentage'].round(1)

# %%
# %matplotlib notebook
#sns.set_style('darkgrid')
width=.75
fig = go.Figure()
plt.figure(figsize=(15, 20))  
colors= ['blue',] * 36

index=0
for i in diff:
    if i:
        colors[index]='crimson'
    index+=1

plt.barh(df['State Name'], df['Voters Turnout Percentage'], width, color=colors)
plt.yticks(np.arange(36), df['State Name'])

for i, v in enumerate(df['Voters Turnout Percentage']):
    plt.text(v+1 , i , str(v), color='black')

# fig.add_layout_image(
#         go.layout.Image(
#             source="https://images.plot.ly/language-icons/api-home/python-logo.png",
#             xref="x",
#             yref="y",
#             x=0,
#             y=20,
#             sizex=15,
#             sizey=20,
#             sizing="stretch",
#             opacity=0.5,
#             layer="below")
# )
plt.grid(color='blue', linestyle='-', linewidth=0.25, alpha=.25)
plt.xlabel('Percentage')
plt.ylabel('State')
plt.title('Voters Turnout Percentage Statewise')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.axis([0, 100, None, None])
plt.text(80, 37, 'Blue with more male voters',bbox=dict(facecolor='blue', alpha=0.5))
plt.text(80, 36, 'Red with more female voters', bbox=dict(facecolor='crimson', alpha=0.5))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1798">

# %%
plt.savefig('malefemalevoters.png')

# %%
other = df['Other '].sum()
print(other)
# Out:
# 5663

# %% [markdown]
# The government schemes such as Ujjawala Yojana, Beti Bachao, the PM Jan Dhan, the Sukanya Samridhi Yojana are some of women centric schemes aimed for empowering them. As such one particular community the 'Other' gender remain to be neglected even in recent times.
#
# The total number of votes casted by the 'Other' gender in the 2019 Indian elections is 38,325. In Census 2011, there were around 4.9lakh people of other gender which was reveled in 2014. According to estimates, this number is off by 4 to 7 times.
#
# In 2014, India’s Supreme Court officially recognized the third gender. The decision means the government must provide equal opportunities and legal and constitutional protection to trans people. However, Transgender Persons (Protection of Rights) Bill 2016, remains controversial. Only those who can afford surgery and present a medical certificate are considered Transgenders and are allowed to register as the third gender, and not the ones who identify themselves as one.
#
# The difference between Census 2011 data and the 'Other' gender vote counts remain as not accepted transgenders.The fundamental rights of the Constitution don't apply for them. The community suffers as they are not even considered citizens of India.
#
# This community is untapped potential voter, if politicial parties try to remove the restraints. They have a long history and are considered auspicious on several occasions among different cultures. They can even be traced back to the Ramayan era.
