# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
filename = 'PM Modi Foreign Visits.xls'
df = pd.read_excel(filename)

# %%
df = df.iloc[:,[1,4,5]]
print(df.head())
df['Expenses incurred on Chartered Flight (Rs.)'] = [0 if(x=='IAF BBJ Aircraft' or x=='Bill not received') 
                                                     else x for x in df['Expenses incurred on Chartered Flight (Rs.)']]
print(df)
df = df[df['Expenses incurred on Chartered Flight (Rs.)']>0.0]
print(df)
# Out:
#   Place of Visit  No of Days Expenses incurred on Chartered Flight (Rs.)
# 0         Bhutan         1.0                                    24527465
# 1         Brazil         4.0                                   203548000
# 2          Nepal         2.0                            IAF BBJ Aircraft
# 3          Japan         4.0                                   134758000
# 4            USA         6.0                                   190460000
#    Place of Visit  No of Days  Expenses incurred on Chartered Flight (Rs.)
# 0          Bhutan         1.0                                   24527465.0
# 1          Brazil         4.0                                  203548000.0
# 2           Nepal         2.0                                          0.0
# 3           Japan         4.0                                  134758000.0
# 4             USA         6.0                                  190460000.0
# ..            ...         ...                                          ...
# ...

# %%
df1 = df.groupby('Place of Visit').sum()

# %%
x9 = df1.index.get_level_values(0).tolist()
print(x9)
# Out:
# ['Afghanistan', 'Australia', 'Belgium', 'Bhutan', 'Brazil', 'Canada', 'China', 'China ', 'Fiji', 'France', 'Germany', 'Germany ', 'Indonesia', 'Ireland', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kyrgyzstan', 'Laos', 'Malaysia', 'Mauritius', 'Mexico', 'Mongolia', 'Mozambique', 'Myanmar', 'Nepal', 'Netherlands', 'Oman', 'Pakistan', 'Palestine', 'Philippines', 'Portugal', 'Qatar', 'Russia', 'Rwanda', 'Saudi Arabia', 'Seychelles', 'Singapore', 'South Africa', 'South Korea', 'Spain', 'Sri Lanka', 'Sweden', 'Switzerland', 'Tajikistan', 'Tanzania', 'Turkey', 'Turkmenistan', 'UAE', 'UK', 'USA', 'Uganda', 'Uzbekistan', 'Vietnam']

# %%
# %matplotlib notebook
df1['No of Days'].plot.bar(color='b', align='center')
plt.xlabel('Countries')
plt.ylabel('No. Of Days')
plt.xticks([r for r in range(57)],x9, rotation=90)
plt.title('No. of Days Spent in Countries')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="902">

# %%
plt.savefig('Abroad.png')

# %%
# %matplotlib notebook
df1['Expenses incurred on Chartered Flight (Rs.)'].plot.bar(color='g', align='center', 
                                                            edgecolor='white')
plt.xlabel('Countries')
plt.ylabel('Expenses incurred on Chartered Flight (Rs.)')
plt.xticks([r for r in range(57)],x9, rotation=90)
plt.title('Expenses of flights while visiting countries by PM Modi')
plt.ticklabel_format(style='plain', axis='y')
plt.axis([None, None, 0, 500000000])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="948">

# %%
plt.savefig('FlightsExpenditure.png')

# %%
fdi = pd.read_excel('FDITopInvesting.xls')
fdi = fdi.iloc[:,[0,1,2,3,4,5,6]]
print(fdi)
# Out:
#    Ranks      Country  2016-17(April–March)  2017-18(April–March)  \
# 0      1    MAURITIUS                 15728                 15941
# 1      2    SINGAPORE                  8711                 12180
# 2      3        JAPAN                  4709                  1633
# 3      4  NETHERLANDS                  3367                  2800
# 4      5         U.K.                  1483                   847
# 5      6       U.S.A.                  2379                  2095
# 6      7      GERMANY                  1069                  1124
# 7      8       CYPRUS                   604                   417
# 8      9          UAE                   675                  1050
# 9     10       FRANCE                   614                   511
#
#    2018-19(April–March)  Cumulative Inflows (April,00-March,19)  \
# 0                  8084                                  134469
# 1                 16228                                   82998
# ...

# %%
x = fdi.iloc[:,1]
x1 = fdi.iloc[:,2]
x2 = fdi.iloc[:,3]
x3 = fdi.iloc[:,4]
x4 = fdi.iloc[:,5]
x5 = fdi.iloc[:,6]

# %%
print(x5)
# Out:
# 0    32
# 1    20
# 2     7
# 3     7
# 4     6
# 5     6
# 6     3
# 7     2
# 8     2
# 9     2
# Name: %age to total\nInflows(in terms of US $)\n, dtype: int64

# %%
# %matplotlib notebook
r = np.arange(10)
plt.bar(r, x5, color='b', align='center', width=bw, edgecolor='white', label='Countries')
plt.xticks([r for r in range(10)], ['Mauritius', 'Singapore', 'Japan', 'Netherlands', 'U.K.',
                                         'U.S.A.', 'Germany', 'Cyprus', 'UAE', 'France'], rotation=45)
plt.ylabel('Percentage')
plt.xlabel('Countries')
plt.title('% to Total FDI Inflow Country Wise')
plt.axis([None, None ,0,35])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="821">

# %%
plt.savefig('%FDI.png')

# %%
# %matplotlib notebook
bw = 0.25
r1 = np.arange(10)
plt.bar(r1, x1, color='b', align='center', width=bw, edgecolor='white', label='2016-17')
plt.bar(r1 + bw, x2, color='g', align='center', width=bw, edgecolor='white', label='2017-118')
plt.bar(r1 + 2*bw, x3, color='r', align='center', width=bw, edgecolor='white', label='2018-19')
plt.xticks([r + bw for r in range(10)], ['Mauritius', 'Singapore', 'Japan', 'Netherlands', 'U.K.',
                                         'U.S.A.', 'Germany', 'Cyprus', 'UAE', 'France'], rotation=45)

plt.ylabel('Investment of US$ in Millions')
plt.xlabel('Countries')
plt.legend()
plt.title('Top Investing Countries FDI Equity Inflows In India')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="953">

# %%
plt.savefig('yearwiseFDI.png')
